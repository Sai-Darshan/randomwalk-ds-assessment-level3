# %%
import pandas as pd

# %%
book_tags=pd.read_csv('book_tags.csv')
books=pd.read_csv('books.csv')
ratings=pd.read_csv('ratings.csv')

# %%
book_tags
# Out:
#        goodreads_book_id  tag_id  count
# 0                    386   30574    565
# 1                    386   19733    280
# 2                    386   21689    182
# 3                    386   21773     99
# 4                    386   19742     78
# ...                  ...     ...    ...
# 40195           31845516   13254      7
# 40196           31845516   19734      7
# 40197           31845516     833      7
# 40198           31845516   23471      6
# 40199           31845516    9477      6
#
# [40200 rows x 3 columns]

# %%
books
# Out:
#      book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0         15              48855         48855   3532896          710
# 1         40              19501         19501   3352398          185
# 2         81               7445          7445   2944133           92
# 3         82               1845          1845   3284484          108
# 4         87               1617          1617    265616          109
# ..       ...                ...           ...       ...          ...
# 394     9788           23399022      23399022  42955411           21
# 395     9847           20685373      20685373  40000267           18
# 396     9887             503248        503248    491309           21
# 397     9960             127970        127970   1066433           26
# 398     9968             554674        554674    548132           34
#
#            isbn        isbn13  \
# 0     553296981  9.780553e+12
# 1     143038419  9.780143e+12
# 2    074324754X  9.780743e+12
# ...

# %%
ratings
# Out:
#         user_id  book_id  rating
# 0             8     2584       5
# 1             4       87       5
# 2             4      495       4
# 3             9      344       4
# 4             9      372       4
# ...         ...      ...     ...
# 233378    36947     6939       5
# 233379    22352      617       2
# 233380    42785     1613       4
# 233381    10622      610       5
# 233382    35336      317       5
#
# [233383 rows x 3 columns]

# %% [markdown]
# *__1.How many books do not have an original title [books.csv]?__*

# %%
books_without_title = books["original_title"].isnull().sum()
print("No of books without an original title:", books_without_title)
# Out:
# No of books without an original title: 36

# %% [markdown]
# *__2. Number of unique books after removing null values:__*

# %%
books = books.dropna(subset=["original_title"])

unique_books = books["book_id"].nunique()
print("No of unique books:", unique_books)
# Out:
# No of unique books: 363

# %% [markdown]
# *__3. Number of unique users:__*

# %%
unique_users = ratings["user_id"].nunique()
print(f'Unique users:{unique_users}')
# Out:
# Unique users:40836

# %% [markdown]
# *__4. Number of unique tags:__*

# %%
unique_tags = book_tags["tag_id"].nunique()
print("Unique tags:", unique_tags)
# Out:
# Unique tags: 3651

# %% [markdown]
# *__5. Most frequentlu used tag_id__*

# %%
most_freq_tag_id = book_tags["tag_id"].value_counts().index[0]
print("Most frequently used tag_id:", most_freq_tag_id)
# Out:
# Most frequently used tag_id: 4600

# %% [markdown]
# *__6. Book with most tag counts__*

# %%
merged_data = books.merge(book_tags, on="goodreads_book_id")

most_tagged_book = merged_data.groupby("original_title")["count"].sum().sort_values(ascending=False).index[0]
print("Book with most tag counts:", most_tagged_book)
# Out:
# Book with most tag counts: Bossypants

# %% [markdown]
# *__7. Plot a bar chart with top 20 unique tags in descending order of ‘user records’ (the number of users tagged the given tag_id with the goodreads_book_id)__*

# %%
import matplotlib.pyplot as plt

# %%
top_20_tags = book_tags.groupby("tag_id")["count"].sum().sort_values(ascending=False).head(20)
top_20_tags.plot(kind="bar")

plt.xlabel("Tag ID")
plt.ylabel("Number of User Records")

plt.title("Top 20 Tags by User Records")
plt.tight_layout()
plt.show()

# %%
book.columns
